# %% [markdown]
# <a href="https://colab.research.google.com/github/TanmayMalewar/portfolio/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn

# %%
import pandas as pd

data = {
    "label": [
        "spam","ham","spam","ham","spam","ham",
        "spam","ham","spam","ham","spam","ham"
    ],

    "message": [
        "Win money now",
        "Hello bro",
        "Claim free recharge",
        "How are you",
        "Limited time offer",
        "Let's study together",
        "Congratulations you won prize",
        "Good morning",
        "Click here to win iphone",
        "Are you coming today",
        "Free cash reward",
        "See you tomorrow"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#    label                        message
# 0   spam                  Win money now
# 1    ham                      Hello bro
# 2   spam            Claim free recharge
# 3    ham                    How are you
# 4   spam             Limited time offer
# 5    ham           Let's study together
# 6   spam  Congratulations you won prize
# 7    ham                   Good morning
# 8   spam       Click here to win iphone
# 9    ham           Are you coming today
# 10  spam               Free cash reward
# 11   ham               See you tomorrow

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

cv = CountVectorizer()

X = cv.fit_transform(df["message"])

Y = df["label"]

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

model = MultinomialNB()

model.fit(X_train, Y_train)

prediction = model.predict(X_test)

accuracy = accuracy_score(Y_test, prediction)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
message = ["hello firend"]

data = cv.transform(message)

result = model.predict(data)

print(result[0])
# Out:
# ham
